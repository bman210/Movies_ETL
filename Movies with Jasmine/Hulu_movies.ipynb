# %%
import pandas as pd
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')

# %%
link = 'Resources/hulu_titles.csv'
hulu_df = pd.read_csv(link)
hulu_df
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                    Silent Night      NaN   NaN
# 2         s3    Movie                    The Marksman      NaN   NaN
# 3         s4    Movie                            Gaia      NaN   NaN
# 4         s5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# ...

# %%
hulu_df.drop(columns =['date_added','duration','rating','director','show_id'], inplace = True)

# %%
hulu_df.dropna(subset = ['country'], inplace = True)

# %%
hulu_movie = hulu_df.loc[hulu_df['type']=='Movie']

# %%
hulu_movie.rename(columns={'listed_in':'genre'}, inplace =True)

# %%
hulu_movie['Streaming Service']='hulu'
hulu_movie
# Out:
#        type                           title  cast         country  \
# 50    Movie  Yashahime: Princess Half-Demon   NaN           Japan
# 65    Movie               Finding Your Feet   NaN  United Kingdom
# 91    Movie                          Dr. No   NaN  United Kingdom
# 93    Movie            Escape from Alcatraz   NaN   United States
# 96    Movie           From Russia With Love   NaN  United Kingdom
# ...     ...                             ...   ...             ...
# 2951  Movie               All Saints (1998)   NaN       Australia
# 2955  Movie                      Getting On   NaN  United Kingdom
# 2958  Movie              (Sub) Ninja Scroll   NaN           Japan
# 2959  Movie           Packed to the Rafters   NaN       Australia
# 2993  Movie  Amy Winehouse: A Final Goodbye   NaN  United Kingdom
#
#       release_year                               genre  \
# 50            2020                               Anime
# 65            2017              Comedy, Drama, Romance
# ...

# %%
hulu_movie.drop(columns=['type','cast'],inplace = True)

# %%
hulu_movie
# Out:
#                                title         country  release_year  \
# 50    Yashahime: Princess Half-Demon           Japan          2020
# 65                 Finding Your Feet  United Kingdom          2017
# 91                            Dr. No  United Kingdom          1962
# 93              Escape from Alcatraz   United States          1979
# 96             From Russia With Love  United Kingdom          1964
# ...                              ...             ...           ...
# 2951               All Saints (1998)       Australia          1998
# 2955                      Getting On  United Kingdom          2009
# 2958              (Sub) Ninja Scroll           Japan          1993
# 2959           Packed to the Rafters       Australia          2008
# 2993  Amy Winehouse: A Final Goodbye  United Kingdom          2011
#
#                                    genre  \
# 50                                 Anime
# 65                Comedy, Drama, Romance
# ...

# %%
hulu_movie.to_csv('Finalized CSV/hulu_movies.csv',index = False, header = True)
