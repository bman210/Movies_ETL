# %%
import pandas as pd
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')

# %%
link = 'Resources/disney_plus_titles.csv'
disney_df = pd.read_csv(link)
disney_df
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
disney_df.drop(columns =['date_added','duration','rating','director','show_id'], inplace = True)

# %%
disney_df.dropna(subset = ['country'], inplace = True)

# %%
disney_movie = disney_df.loc[disney_df['type']=='Movie']

# %%
disney_movie.rename(columns={'listed_in':'genre'}, inplace =True)

# %%
disney_movie['Streaming Service']='Disney'
disney_movie
# Out:
#        type                                           title  \
# 2     Movie                    Ice Age: A Mammoth Christmas
# 5     Movie                               Becoming Cousteau
# 9     Movie           A Muppets Christmas: Letters To Santa
# 12    Movie                                 The Pixar Story
# 19    Movie                                       Enchanted
# ...     ...                                             ...
# 1445  Movie                        X-Men Origins: Wolverine
# 1446  Movie  Night at the Museum: Battle of the Smithsonian
# 1447  Movie                                 Eddie the Eagle
# 1448  Movie                            Bend It Like Beckham
# 1449  Movie           Captain Sparky vs. The Flying Saucers
#
#                                                    cast  \
# 2     Raymond Albert Romano, John Leguizamo, Denis L...
# 5                 Jacques Yves Cousteau, Vincent Cassel
# 9     Steve Whitmire, Dave Goelz, Bill Barretta, Eri...
# ...

# %%
disney_movie.drop(columns=['type'],inplace = True)

# %%
disney_movie
# Out:
#                                                title  \
# 2                       Ice Age: A Mammoth Christmas
# 5                                  Becoming Cousteau
# 9              A Muppets Christmas: Letters To Santa
# 12                                   The Pixar Story
# 19                                         Enchanted
# ...                                              ...
# 1445                        X-Men Origins: Wolverine
# 1446  Night at the Museum: Battle of the Smithsonian
# 1447                                 Eddie the Eagle
# 1448                            Bend It Like Beckham
# 1449           Captain Sparky vs. The Flying Saucers
#
#                                                    cast  \
# 2     Raymond Albert Romano, John Leguizamo, Denis L...
# 5                 Jacques Yves Cousteau, Vincent Cassel
# 9     Steve Whitmire, Dave Goelz, Bill Barretta, Eri...
# 12    Stacy Keach, John Lasseter, Brad Bird, John Mu...
# ...

# %%
disney_movie.drop(columns=['cast'], inplace = True)

# %%
disney_movie.to_csv('Finalized CSV/Disney_movies.csv',index = False, header = True)
