# %%
import pandas as pd
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')

# %%
link = 'Resources/amazon_prime_titles.csv'
amazon_df = pd.read_csv(link)
amazon_df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
amazon_df.drop(columns =['date_added','duration','rating','director','show_id','cast'], inplace = True)
#amazon_tv = amazon_df.loc[amazon_df['type']=='TV Show']

# %%
amazon_df.head(15)
# Out:
#      type                              title         country  release_year  \
# 0   Movie                The Grand Seduction          Canada          2014
# 1   Movie               Take Care Good Night           India          2018
# 2   Movie               Secrets of Deception   United States          2017
# 3   Movie                 Pink: Staying True   United States          2014
# 4   Movie                      Monster Maker  United Kingdom          1989
# 5   Movie              Living With Dinosaurs  United Kingdom          1989
# 6   Movie                          Hired Gun   United States          2017
# 7   Movie                       Grease Live!   United States          2016
# 8   Movie                    Global Meltdown          Canada          2017
# 9   Movie                     David's Mother   United States          1994
# 10  Movie                     Forest Fairies          Canada          2016
# ...

# %%
amazon_df.dropna(subset = ['country'], inplace = True)
amazon_df
# Out:
#        type                  title         country  release_year  \
# 0     Movie    The Grand Seduction          Canada          2014
# 1     Movie   Take Care Good Night           India          2018
# 2     Movie   Secrets of Deception   United States          2017
# 3     Movie     Pink: Staying True   United States          2014
# 4     Movie          Monster Maker  United Kingdom          1989
# ...     ...                    ...             ...           ...
# 9604  Movie             Bride Wars   United States          2009
# 9614  Movie  What Happens in Vegas   United States          2008
# 9641  Movie            Marley & Me   United States          2008
# 9643  Movie     Love & Other Drugs   United States          2010
# 9644  Movie   Little Miss Sunshine   United States          2006
#
#                     listed_in  \
# 0               Comedy, Drama
# 1        Drama, International
# 2     Action, Drama, Suspense
# 3                 Documentary
# ...

# %%
amazon_df.dtypes
# Out:
# type            object
# title           object
# country         object
# release_year     int64
# listed_in       object
# description     object
# dtype: object

# %%
amazon_movie = amazon_df.loc[amazon_df['type']=='Movie']
amazon_movie
# Out:
#        type                  title         country  release_year  \
# 0     Movie    The Grand Seduction          Canada          2014
# 1     Movie   Take Care Good Night           India          2018
# 2     Movie   Secrets of Deception   United States          2017
# 3     Movie     Pink: Staying True   United States          2014
# 4     Movie          Monster Maker  United Kingdom          1989
# ...     ...                    ...             ...           ...
# 9604  Movie             Bride Wars   United States          2009
# 9614  Movie  What Happens in Vegas   United States          2008
# 9641  Movie            Marley & Me   United States          2008
# 9643  Movie     Love & Other Drugs   United States          2010
# 9644  Movie   Little Miss Sunshine   United States          2006
#
#                     listed_in  \
# 0               Comedy, Drama
# 1        Drama, International
# 2     Action, Drama, Suspense
# 3                 Documentary
# ...

# %%
amazon_movie.dropna(subset = ['country'], inplace = True)

# %%
amazon_movie.drop(columns=['type'],inplace = True)

# %% [markdown]
# ###### amazon_movie.rename(columns = {'listed_in':'genre'}, inplace = True)
# amazon_movie

# %%
amazon_movie.rename(columns={'listed_in':'genre','cast':"movie_cast"}, inplace =True)
amazon_movie
# Out:
#                       title         country  release_year  \
# 0       The Grand Seduction          Canada          2014
# 1      Take Care Good Night           India          2018
# 2      Secrets of Deception   United States          2017
# 3        Pink: Staying True   United States          2014
# 4             Monster Maker  United Kingdom          1989
# ...                     ...             ...           ...
# 9604             Bride Wars   United States          2009
# 9614  What Happens in Vegas   United States          2008
# 9641            Marley & Me   United States          2008
# 9643     Love & Other Drugs   United States          2010
# 9644   Little Miss Sunshine   United States          2006
#
#                         genre  \
# 0               Comedy, Drama
# 1        Drama, International
# 2     Action, Drama, Suspense
# 3                 Documentary
# 4              Drama, Fantasy
# ...                       ...
# 9604                   Comedy
# ...

# %%
amazon_movie['Streaming Service']='Amazon'
amazon_movie
# Out:
#                       title         country  release_year  \
# 0       The Grand Seduction          Canada          2014
# 1      Take Care Good Night           India          2018
# 2      Secrets of Deception   United States          2017
# 3        Pink: Staying True   United States          2014
# 4             Monster Maker  United Kingdom          1989
# ...                     ...             ...           ...
# 9604             Bride Wars   United States          2009
# 9614  What Happens in Vegas   United States          2008
# 9641            Marley & Me   United States          2008
# 9643     Love & Other Drugs   United States          2010
# 9644   Little Miss Sunshine   United States          2006
#
#                         genre  \
# 0               Comedy, Drama
# 1        Drama, International
# 2     Action, Drama, Suspense
# 3                 Documentary
# 4              Drama, Fantasy
# ...                       ...
# 9604                   Comedy
# ...

# %%
amazon_movie.to_csv('Finalized CSV/Amazon_movies.csv',index = False, header = True)

# %%
connection_string = "postgres:postgres@localhost:5432/Project_2_movies"
engine = create_engine(f'postgresql://{connection_string}')

# %%
premise_transformed.to_sql(name='premise', con=engine, if_exists='append', index=True)
