# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
link = 'Resources/amazon_prime_titles.csv'
amazon_df = pd.read_csv(link)
amazon_df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
amazon_df.drop(columns =['date_added','duration','rating','release_year','director','show_id'], inplace = True)
#amazon_tv = amazon_df.loc[amazon_df['type']=='TV Show']

# %%
amazon_tv.head(15)
# Out:
#    show_id     type                                              title  \
# 17     s18  TV Show                                         Zoo Babies
# 18     s19  TV Show                      Zoë Coombs Marr: Bossy Bottom
# 20     s21  TV Show                                         Zoboomafoo
# 21     s22  TV Show                          Zo Zo Zombie: Mini-Series
# 23     s24  TV Show                                       ZeroZeroZero
# 26     s27  TV Show                                 Zahara: The Return
# 27     s28  TV Show                     Z: The Beginning of Everything
# 28     s29  TV Show                                    Yu-Gi-Oh! Zexal
# 29     s30  TV Show                                    Yu-Gi-Oh! ARC-V
# 30     s31  TV Show                                     Yu-Gi-Oh! 5D's
# 31     s32  TV Show                              Your Bleeped Up Brain
# 35     s36  TV Show                                        Young Lions
# ...

# %%
amazon_tv.dropna(subset = ['country'])
print(amazon_tv)
# Out:
#      show_id     type                                      title  \
# 23       s24  TV Show                               ZeroZeroZero
# 27       s28  TV Show             Z: The Beginning of Everything
# 66       s67  TV Show  World’s Toughest Race: Eco-Challenge Fiji
# 84       s85  TV Show                                 Wishenpoof
# 206     s207  TV Show                                     Utopia
# ...      ...      ...                                        ...
# 8453   s8454  TV Show                              Voltaire High
# 8701   s8702  TV Show                                Do, Re & Mi
# 8746   s8747  TV Show                                Dinner Club
# 9321   s9322  TV Show               If You Give a Mouse a Cookie
# 9584   s9585  TV Show                                   Red Oaks
#
#                                                    cast        country  \
# 23    ANDREA RISEBOROUGH, HAROLD TORRES, CLAUDIA PIN...          Italy
# 27                      Christina Ricci
# ...

# %%
amazon_tv.dtypes
# Out:
# show_id        object
# type           object
# title          object
# cast           object
# country        object
# listed_in      object
# description    object
# dtype: object

# %%
amazon_movie = amazon_df.loc[amazon_df['type']=='Movie']
amazon_movie
# Out:
#        type                 title  \
# 0     Movie   The Grand Seduction
# 1     Movie  Take Care Good Night
# 2     Movie  Secrets of Deception
# 3     Movie    Pink: Staying True
# 4     Movie         Monster Maker
# ...     ...                   ...
# 9660  Movie    The Man in the Hat
# 9662  Movie                 River
# 9663  Movie   Pride Of The Bowery
# 9665  Movie               Outpost
# 9667  Movie           Harry Brown
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# ...                                                 ...             ...
# ...

# %%
amazon_movie.dropna(subset = ['country'], inplace = True)
# Out:
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
amazon_movie.drop(columns=['type'],inplace = True)
# Out:
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
amazon_movie
# Out:
#                       title  \
# 0       The Grand Seduction
# 1      Take Care Good Night
# 2      Secrets of Deception
# 3        Pink: Staying True
# 4             Monster Maker
# ...                     ...
# 9604             Bride Wars
# 9614  What Happens in Vegas
# 9641            Marley & Me
# 9643     Love & Other Drugs
# 9644   Little Miss Sunshine
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# ...                                                 ...             ...
# 9604  Kate Hudson, Anne Hathaway, Kristen Johnston, ...   United States
# ...

# %%
amazon_movie['listed_in'] = amazon_movie['listed_in'].replace({'listed_in':'genre'})
amazon_movie
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9932\3425083712.py in <module>
# ----> 1 amazon_movie['listed_in'] = amazon_movie['listed_in'].replace({'listed_in':'genre'})
#       2 amazon_movie
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# D:\school files\Certificate course\anaconda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
# ...
